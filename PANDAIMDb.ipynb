# %%
import pandas as pd
# read data from  .csv file
data=pd.read_csv('IMDB-Movie-Data.csv')
# read data with specifi index
data_indexed=pd.read_csv('IMDB-Movie-Data.csv',index_col='Title')
# view Data
# head() and tail()
# head() returns top 5 rows ,Parameter:no.of rows to be selected
# tail():return bottom 5 rows of the dataset

data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
genre=data['Genre']

# %%
data_indexed.loc[['Split']][['Genre','Actors','Director','Rating','Revenue (Millions)','Metascore']]
# Out:
#                  Genre                                             Actors  \
# Title
# Split  Horror,Thriller  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
#
#                  Director  Rating  Revenue (Millions)  Metascore
# Title
# Split  M. Night Shyamalan     7.3              138.12       62.0

# %%
data.iloc[10:15][['Genre','Actors','Director','Rating','Revenue (Millions)','Metascore']]
# Out:
#                          Genre  \
# 10    Adventure,Family,Fantasy
# 11     Biography,Drama,History
# 12     Action,Adventure,Sci-Fi
# 13  Animation,Adventure,Comedy
# 14         Action,Comedy,Drama
#
#                                                Actors         Director  \
# 10  Eddie Redmayne, Katherine Waterston, Alison Su...      David Yates
# 11  Taraji P. Henson, Octavia Spencer, Janelle Mon...   Theodore Melfi
# 12  Felicity Jones, Diego Luna, Alan Tudyk, Donnie...   Gareth Edwards
# 13  Auli'i Cravalho, Dwayne Johnson, Rachel House,...     Ron Clements
# 14  Anne Hathaway, Jason Sudeikis, Austin Stowell,...  Nacho Vigalondo
#
#     Rating  Revenue (Millions)  Metascore
# 10     7.5              234.02       66.0
# 11     7.8              169.27       74.0
# 12     7.9              532.17       65.0
# 13     7.7              248.75       81.0
# 14     6.4                2.87       70.0

# %%
# data selection based on conditional filtering
# suppose we want to select  movie with following conditon:
# 1: release from 2010 to 2016
# 2:Rating less than 6.0
# 3: revenue topped
data[((data['Year']>=2010) & (data['Year']<=2016)) & (data['Rating']<6.0) & (data['Revenue (Millions)']>data['Revenue (Millions)'].quantile(.943))]
# Out:
#      Rank                                      Title                    Genre  \
# 366   367  The Twilight Saga: Breaking Dawn - Part 2  Adventure,Drama,Fantasy
# 941   942                 The Twilight Saga: Eclipse  Adventure,Drama,Fantasy
#
#                                            Description     Director  \
# 366  After the birth of Renesmee, the Cullens gathe...  Bill Condon
# 941  As a string of mysterious killings grips Seatt...  David Slade
#
#                                                 Actors  Year  \
# 366  Kristen Stewart, Robert Pattinson, Taylor Laut...  2012
# 941  Kristen Stewart, Robert Pattinson, Taylor Laut...  2010
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 366                115     5.5  194329              292.30       52.0
# 941                124     4.9  192740              300.52       58.0

# %%
data.iloc[366]
# Out:
# Rank                                                                367
# Title                         The Twilight Saga: Breaking Dawn - Part 2
# Genre                                           Adventure,Drama,Fantasy
# Description           After the birth of Renesmee, the Cullens gathe...
# Director                                                    Bill Condon
# Actors                Kristen Stewart, Robert Pattinson, Taylor Laut...
# Year                                                               2012
# Runtime (Minutes)                                                   115
# Rating                                                              5.5
# Votes                                                            194329
# Revenue (Millions)                                                292.3
# Metascore                                                          52.0
# Name: 366, dtype: object

# %%
data.iloc[941]
# Out:
# Rank                                                                942
# Title                                        The Twilight Saga: Eclipse
# Genre                                           Adventure,Drama,Fantasy
# Description           As a string of mysterious killings grips Seatt...
# Director                                                    David Slade
# Actors                Kristen Stewart, Robert Pattinson, Taylor Laut...
# Year                                                               2010
# Runtime (Minutes)                                                   124
# Rating                                                              4.9
# Votes                                                            192740
# Revenue (Millions)                                               300.52
# Metascore                                                          58.0
# Name: 941, dtype: object
